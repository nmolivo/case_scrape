# %%
import sys

# %%
print(sys.path)
# Out:
# ['/Users/nmolivo/Documents/Repos/case_scrape/notebooks', '/Users/nmolivo/anaconda3/envs/cuya-courts/lib/python38.zip', '/Users/nmolivo/anaconda3/envs/cuya-courts/lib/python3.8', '/Users/nmolivo/anaconda3/envs/cuya-courts/lib/python3.8/lib-dynload', '', '/Users/nmolivo/.local/lib/python3.8/site-packages', '/Users/nmolivo/anaconda3/envs/cuya-courts/lib/python3.8/site-packages', '/Users/nmolivo/anaconda3/envs/cuya-courts/lib/python3.8/site-packages/IPython/extensions', '/Users/nmolivo/.ipython']

# %%
sys.path.append("/Users/nmolivo/Documents/Repos/case_scrape")

# %%
import pandas as pd
from sqlalchemy import create_engine
from sqlalchemy.orm import Session, sessionmaker, scoped_session
from chromedriver_py import binary_path
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import WebDriverWait, Select
from selenium.webdriver.support import expected_conditions as EC
from sqlalchemy.util.compat import contextmanager
from selenium.common.exceptions import NoSuchElementException
import random

# %%
from case_scrape.case_scrape import *

# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
opts = Options()
# opts.headless = True
#driver = webdriver.Chrome(options=opts, executable_path=binary_path)

# %%
range_start = 624667

# %%
case_numbers = [str(x) for x in range(range_start, range_start+100)]

# %%
import sqlalchemy


opts = Options()
# opts.headless = True
driver = webdriver.Chrome(ChromeDriverManager().install(), options=opts)#, executable_path=binary_path)

def search_case_number(driver, case_number) -> webdriver.Chrome:
    """upon landing on the search page, this function will navigate the agreement and then enter a case 
    number to search criminal records and click the submit button.
    Be sure to already be on the case search page when you run this function."""
    WebDriverWait(driver, 10).until(
        EC.element_to_be_clickable((By.XPATH, "//*[(@id = 'SheetContentPlaceHolder_rbCrCase')]"))).click()
    driver.implicitly_wait(2)
    
    if len(driver.find_elements(By.ID, "SheetContentPlaceHolder_btnYes")) > 0:
        WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.ID, "SheetContentPlaceHolder_btnYes"))).click()
        WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.XPATH, "//*[(@id = 'SheetContentPlaceHolder_rbCrCase')]"))).click()
        driver.implicitly_wait(3)

    text_box = driver.find_element(By.XPATH, "//input[(@type = 'text')]")
    text_box.clear()
    text_box.send_keys(case_number)
    WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.ID, "SheetContentPlaceHolder_criminalCaseSearch_btnSubmitCase"))).click()
    driver.implicitly_wait(random.randint(4,15))

def get_table(case_number: str, header_xpath: str, data_xpath: str) -> pd.DataFrame:
    headers = driver.find_elements(By.XPATH, header_xpath)
    data = driver.find_elements(By.XPATH, data_xpath)
    data_list = [d.text for d in data]
    table = {}
    for i, h in enumerate(headers):
        table[h.text.upper()]=data_list[i::len(headers)]
    df = pd.DataFrame(table)
    df["CASE_NUMBER"] = case_number
    return df

def write_pandas_df_to_db(db, df: pd.DataFrame, table_to_write_to: str):
    engine = db.get_engine()
    listToWrite = df.to_dict(orient='records')
    conn = engine.connect()

    metadata = sqlalchemy.schema.MetaData(bind=engine,reflect=True)
    table = sqlalchemy.Table(table_to_write_to, metadata, autoload=True)

    # Open the session
    Session = sessionmaker(bind=engine)
    session = Session()

    # Inser the dataframe into the database in one bulk
    conn.execute(table.insert(), listToWrite)

def fetch_case_summary(db, driver) -> str:
    """commits returns case_number"""
    WebDriverWait(driver,10).until(EC.element_to_be_clickable((By.XPATH, "//*[(@id = 'SheetContentPlaceHolder_caseSummary_lblCaseNumber')]")))
    case_number = driver.find_element(By.XPATH, "//*[(@id = 'SheetContentPlaceHolder_caseSummary_lblCaseNumber')]").text
    case_information=CaseInformation(
        number= case_number,
        status=driver.find_element(By.XPATH, "//*[(@id = 'SheetContentPlaceHolder_caseSummary_lblCaseStatus')]").text,
        judge_name=driver.find_element(By.XPATH, "//*[(@id = 'SheetContentPlaceHolder_caseSummary_lblJudgeName')]").text,
        next_event=driver.find_element(By.XPATH, "//*[(@id = 'SheetContentPlaceHolder_caseSummary_lblNextEvent')]").text,
        arrested_date=driver.find_element(By.XPATH, "//*[(@id = 'SheetContentPlaceHolder_caseSummary_lblArrested')]").text,
        arresting_agency=driver.find_element(By.XPATH, "//*[(@id = 'SheetContentPlaceHolder_caseSummary_lblArrestingAgency')]").text,
        arresting_agency_report=driver.find_element(By.XPATH, "//*[(@id = 'SheetContentPlaceHolder_caseSummary_lblArestingAgencyReport')]").text,
        court_of_appeals_case=driver.find_element(By.XPATH, "//*[(@id = 'SheetContentPlaceHolder_caseSummary_lblCOACase')]").text
    )
    db.add(case_information)
    defendant_info = DefendantInformation(
        case_number=case_number,
        number=driver.find_element(By.XPATH, "//*[(@id = 'SheetContentPlaceHolder_caseSummary_lblNumber')]").text,
        name=driver.find_element(By.XPATH, "//*[(@id = 'SheetContentPlaceHolder_caseSummary_lblName')]").text,
        status=driver.find_element(By.XPATH, "//*[(@id = 'SheetContentPlaceHolder_caseSummary_defStatus_lblDefStatus')]").text,
        date_of_birth=driver.find_element(By.XPATH, "//*[(@id = 'SheetContentPlaceHolder_caseSummary_lblDOB')]").text,
        race=driver.find_element(By.XPATH, "//*[(@id = 'SheetContentPlaceHolder_caseSummary_lblRace')]").text,
        sex=driver.find_element(By.XPATH, "//*[(@id = 'SheetContentPlaceHolder_caseSummary_lblSex')]").text,
        other_cases=driver.find_element(By.XPATH, "//*[(@id = 'SheetContentPlaceHolder_caseSummary_otherCases_lblOtherCases')]").text,
        co_defendants=driver.find_element(By.XPATH, "//*[(@id = 'SheetContentPlaceHolder_caseSummary_otherDefs_lblCoDefs')]").text
    ) 
    db.add(defendant_info)  
    db.commit()

def fetch_docket(db, driver) -> str:

    # throw in a random scroll?
    if i % 10 ==0:
        print(f"{i}/{len(new_cases)} records completed")

    #additional tables
    charge_df = get_table(case_number, 
                        header_xpath="//table[(@id = 'SheetContentPlaceHolder_caseCharges_gvCharges')]//th", 
                        data_xpath="//table[(@id = 'SheetContentPlaceHolder_caseCharges_gvCharges')]//td")
    write_pandas_df_to_db(db, charge_df, "charges")
    
    bond_df = get_table(case_number, 
                        header_xpath="//table[(@id = 'SheetContentPlaceHolder_caseBondInfo_gvBonds')]//th", 
                        data_xpath="//table[(@id = 'SheetContentPlaceHolder_caseBondInfo_gvBonds')]//td")
    write_pandas_df_to_db(db, bond_df, "bond_information")
    
    action_df = get_table(case_number,
                        header_xpath="//table[(@id = 'SheetContentPlaceHolder_caseActions_gvActions')]//th",
                        data_xpath="//table[(@id = 'SheetContentPlaceHolder_caseActions_gvActions')]//td")
    write_pandas_df_to_db(db, action_df, "case_actions")
    return (driver, case_number)


def retrieve_case_information(db, driver, case_no: str) -> str:
    """using a driver and an agent submitted case_no, which is a 6 digit representation of a case, 
    this function searches the case number and commits data from the results to the database, returns full case number"""
    driver = search_case_number(driver, case_no)
    try:
        if len(driver.find_elements(By.XPATH, "//*[@id='SheetContentPlaceHolder_ctl00_gvCaseResults']")) == 0:
            driver, case_number = fetch_case_summary(db, driver)
            driver = fetch_docket(driver, case_number)
            driver = fetch_cost_info(driver, case_number)
            driver = fetch_defendant(driver, case_number)
            driver = fetch_attorney(driver, case_number)

        else: 
            addl_case_numbers = driver.find_elements(By.XPATH, "//table/tbody/tr/td[count(//table/thead/tr/th[.='$Case Number']/preceding-sibling::th)+1]")
            additional_cases_to_scrape.extend([x for x in addl_case_numbers if x is not None])
            
        driver.implicitly_wait(random.randint(2,20))
        driver.back()
        
    except:
        driver.get("https://cpdocket.cp.cuyahogacounty.us/Search.aspx") 
    return case_number
        
        
    

driver.get("https://cpdocket.cp.cuyahogacounty.us/Search.aspx") 
retrieve_case_information(case_no)
# Out:
# 0/100 records completed
# 10/100 records completed
# 20/100 records completed
# 30/100 records completed
# 40/100 records completed
# 50/100 records completed
# 60/100 records completed
# 70/100 records completed
# 80/100 records completed
# 90/100 records completed

# %%
opts = Options()
# opts.headless = True
driver = webdriver.Chrome(ChromeDriverManager().install(), options=opts)#, executable_path=binary_path)



additional_cases_to_scrape = []

x_case_number = []
x_case_status = []
x_judge_name = []
x_next_event = []
x_arrested_date = []
x_arresting_agency = []
x_arresting_agency_report = []
x_court_of_appeals_case = []
x_defendant_number = []
x_defendant_name = []
x_defendant_status = []
x_defendant_dob = []
x_defendant_race = []
x_defendant_sex = []
x_other_cases = []
x_co_defendants = []
charge_type = []
charge_statute = []
charge_desc = []
charge_disposition = []
bond_number = []
bond_amount = []
bond_type = []
bond_date_set = []
bond_date_posted = []
bond_bond_company = []
event_date = []
event_description = []
charge_dfs = []
actions_dfs = []
bonds_dfs = []

def search_case_number(case_number):
    """upon landing on the search page, this function will navigate the agreement and then enter a case 
    number to search criminal records and click the submit button.
    Be sure to already be on the case search page when you run this function."""
    WebDriverWait(driver, 10).until(
        EC.element_to_be_clickable((By.XPATH, "//*[(@id = 'SheetContentPlaceHolder_rbCrCase')]"))).click()
    driver.implicitly_wait(2)
    
    if len(driver.find_elements(By.ID, "SheetContentPlaceHolder_btnYes")) > 0:
        WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.ID, "SheetContentPlaceHolder_btnYes"))).click()
        WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.XPATH, "//*[(@id = 'SheetContentPlaceHolder_rbCrCase')]"))).click()
        driver.implicitly_wait(3)

    text_box = driver.find_element(By.XPATH, "//input[(@type = 'text')]")
    text_box.clear()
    text_box.send_keys(case_number)
    WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.ID, "SheetContentPlaceHolder_criminalCaseSearch_btnSubmitCase"))).click()
    driver.implicitly_wait(random.randint(4,15))
    return driver

def get_table(case_number: str, header_xpath: str, data_xpath: str) -> pd.DataFrame:
    headers = driver.find_elements(By.XPATH, header_xpath)
    data = driver.find_elements(By.XPATH, data_xpath)
    data_list = [d.text for d in data]
    table = {}
    for i, h in enumerate(headers):
        table[h.text.upper()]=data_list[i::len(headers)]
    df = pd.DataFrame(table)
    df["CASE_NUMBER"] = case_number
    return df
    
    

driver.get("https://cpdocket.cp.cuyahogacounty.us/Search.aspx") 
for i, case_number in enumerate(new_cases):  
    driver = search_case_number(case_number)
    try:
        if len(driver.find_elements(By.XPATH, "//*[@id='SheetContentPlaceHolder_ctl00_gvCaseResults']")) == 0:
            def get_case_summary(driver, case_number):
                WebDriverWait(driver,10).until(EC.element_to_be_clickable((By.XPATH, "//*[(@id = 'SheetContentPlaceHolder_caseSummary_lblCaseNumber')]")))
                case_number = driver.find_element(By.XPATH, "//*[(@id = 'SheetContentPlaceHolder_caseSummary_lblCaseNumber')]").text
                x_case_number.append(case_number)
                x_case_status.append(driver.find_element(By.XPATH, "//*[(@id = 'SheetContentPlaceHolder_caseSummary_lblCaseStatus')]").text)
                x_judge_name.append(driver.find_element(By.XPATH, "//*[(@id = 'SheetContentPlaceHolder_caseSummary_lblJudgeName')]").text)
                x_next_event.append(driver.find_element(By.XPATH, "//*[(@id = 'SheetContentPlaceHolder_caseSummary_lblNextEvent')]").text)
                x_arrested_date.append(driver.find_element(By.XPATH, "//*[(@id = 'SheetContentPlaceHolder_caseSummary_lblArrested')]").text)
                x_arresting_agency.append(driver.find_element(By.XPATH, "//*[(@id = 'SheetContentPlaceHolder_caseSummary_lblArrestingAgency')]").text)
                x_arresting_agency_report.append(driver.find_element(By.XPATH, "//*[(@id = 'SheetContentPlaceHolder_caseSummary_lblArestingAgencyReport')]").text)
                x_court_of_appeals_case.append(driver.find_element(By.XPATH, "//*[(@id = 'SheetContentPlaceHolder_caseSummary_lblCOACase')]").text)
                x_defendant_number.append(driver.find_element(By.XPATH, "//*[(@id = 'SheetContentPlaceHolder_caseSummary_lblNumber')]").text)
                x_defendant_name.append(driver.find_element(By.XPATH, "//*[(@id = 'SheetContentPlaceHolder_caseSummary_lblName')]").text)
                x_defendant_status.append(driver.find_element(By.XPATH, "//*[(@id = 'SheetContentPlaceHolder_caseSummary_defStatus_lblDefStatus')]").text)
                x_defendant_dob.append(driver.find_element(By.XPATH, "//*[(@id = 'SheetContentPlaceHolder_caseSummary_lblDOB')]").text)
                x_defendant_race.append(driver.find_element(By.XPATH, "//*[(@id = 'SheetContentPlaceHolder_caseSummary_lblRace')]").text)
                x_defendant_sex.append(driver.find_element(By.XPATH, "//*[(@id = 'SheetContentPlaceHolder_caseSummary_lblSex')]").text) 
                x_other_cases.append(driver.find_element(By.XPATH, "//*[(@id = 'SheetContentPlaceHolder_caseSummary_otherCases_lblOtherCases')]").text)
                x_co_defendants.append(driver.find_element(By.XPATH, "//*[(@id = 'SheetContentPlaceHolder_caseSummary_otherDefs_lblCoDefs')]").text)

            # throw in a random scroll?
            if i % 10 ==0:
                print(f"{i}/{len(new_cases)} records completed")

            #additional tables
            charge_df = get_table(case_number, 
                                  header_xpath="//table[(@id = 'SheetContentPlaceHolder_caseCharges_gvCharges')]//th", 
                                  data_xpath="//table[(@id = 'SheetContentPlaceHolder_caseCharges_gvCharges')]//td")
            
            bond_df = get_table(case_number, 
                                  header_xpath="//table[(@id = 'SheetContentPlaceHolder_caseBondInfo_gvBonds')]//th", 
                                  data_xpath="//table[(@id = 'SheetContentPlaceHolder_caseBondInfo_gvBonds')]//td")
            
            action_df = get_table(case_number,
                                 header_xpath="//table[(@id = 'SheetContentPlaceHolder_caseActions_gvActions')]//th",
                                 data_xpath="//table[(@id = 'SheetContentPlaceHolder_caseActions_gvActions')]//td")
           
            charge_dfs.append(charge_df)
            bonds_dfs.append(bond_df)
            actions_dfs.append(action_df)
            
        else: 
            
            addl_case_numbers = driver.find_elements(By.XPATH, "//table/tbody/tr/td[count(//table/thead/tr/th[.='$Case Number']/preceding-sibling::th)+1]")
            additional_cases_to_scrape.extend([x for x in addl_case_numbers if x is not None])
            
        driver.implicitly_wait(random.randint(2,20))
        driver.back()
        
    except:
        driver.get("https://cpdocket.cp.cuyahogacounty.us/Search.aspx") 
        
    lists = [x_case_number,
             x_case_status,
             x_judge_name,
             x_next_event,
             x_arrested_date,
             x_arresting_agency,
             x_arresting_agency_report,       
             x_court_of_appeals_case,
             x_defendant_number,
             x_defendant_name,
             x_defendant_status,
             x_defendant_dob,
             x_defendant_race,
             x_defendant_sex,
             x_other_cases,
             x_co_defendants]
    
    the_len = len(x_case_number)
    for lst in lists:
        if len(lst) < the_len:
            lst.append("Not on Page")

# %%
for item in [x_case_number,
x_case_status,
x_judge_name,
x_next_event,
x_arrested_date,
x_arresting_agency,
x_arresting_agency_report,       
x_court_of_appeals_case,
x_defendant_number,
x_defendant_name,
x_defendant_status,
x_defendant_dob,
x_defendant_race,
x_defendant_sex,
x_other_cases,
x_co_defendants]:
    print(len(item))
# Out:
# 85
# 85
# 85
# 85
# 85
# 85
# 85
# 85
# 85
# 85
# 85
# 85
# 85
# 85
# 85
# 85

# %%
df = pd.DataFrame({"CASE_NUMBER": x_case_number,
                   "CASE_STATUS": x_case_status,
                   "JUDGE_NAME": x_judge_name,
                   "NEXT_EVENT": x_next_event,
                   "ARRESTED_DATE": x_arrested_date,
                   "ARRESTING_AGENCY": x_arresting_agency,
                   "ARRESTING_AGENCY_REPORT": x_arresting_agency_report,
                   "COURT_OF_APPEALS_CASE": x_court_of_appeals_case,
                   "DEFENDANT_NUMBER": x_defendant_number,
                   "DEFENDANT_NAME": x_defendant_name,
                   "DEFENDANT_STATUS": x_defendant_status,
                   "DEFENDANT_DOB": x_defendant_dob,
                   "DEFENDANT_RACE": x_defendant_race,
                   "DEFENDANT_SEX": x_defendant_sex,
                   "OTHER_CASES": x_other_cases,
                   "CO_DEFENDANTS": x_co_defendants})

# %%
df.to_csv("data2.csv", index=False)

# %%
charges_csv = pd.concat(charge_dfs, axis = 0, ignore_index=True)

# %%
charges_csv = pd.concat(charge_dfs, axis = 0, ignore_index=True)
actions_csv = pd.concat(actions_dfs, axis=0, ignore_index=True)
bonds_csv = pd.concat(bonds_dfs, axis=0, ignore_index=True)

# %%
bonds_csv.head()
# Out:
#   BOND NUMBER      AMOUNT               TYPE    DATE SET DATE POSTED  \
# 0      699738  $10,000.00  CASH/SUR/PROP/10%  08/15/2017  08/15/2017
# 1      700209  $25,000.00  CASH/SURETY/PROP.  08/24/2017
# 2      700558  $50,000.00  CASH/SURETY/PROP.  08/31/2017
# 3      694631  $20,000.00  CASH/SURETY/PROP.  05/01/2017
# 4      700746  $50,000.00  CASH/SURETY/PROP.  09/06/2017
#
#   BONDSMAN/SURETY CO.     CASE_NUMBER
# 0            CASH / `  CR-17-618926-A
# 1                      CR-17-620395-A
# 2                      CR-17-620395-A
# 3                      CR-17-616872-A
# 4                      CR-17-620865-A

# %%
actions_csv.columns
# Out:
# Index(['BOND NUMBER', 'AMOUNT', 'TYPE', 'DATE SET', 'DATE POSTED',
#        'BONDSMAN/SURETY CO.', 'CASE_NUMBER', 'EVENT DATE',
#        'EVENT DESCRIPTION'],
#       dtype='object')

# %%
actions_csv = actions_csv[["CASE_NUMBER", "EVENT DATE", "EVENT DESCRIPTION"]]

# %%
actions_csv = actions_csv.dropna(subset=["EVENT DATE", "EVENT DESCRIPTION"])

# %%
actions_csv
# Out:
#         CASE_NUMBER  EVENT DATE  EVENT DESCRIPTION
# 120  CR-17-618926-A  03/25/2019            PV HELD
# 121  CR-17-618926-A  02/14/2019            PV HELD
# 122  CR-17-618926-A  06/14/2018            PV HELD
# 123  CR-17-618926-A  01/12/2018            PV HELD
# 124  CR-17-618926-A  12/27/2017            PV HELD
# ..              ...         ...                ...
# 828  CR-21-664021-A  01/11/2022      PRETRIAL HELD
# 829  CR-21-664021-A  12/28/2021      PRETRIAL HELD
# 830  CR-21-664021-A  12/14/2021      PRETRIAL HELD
# 831  CR-21-664021-A  11/15/2021  INDICTED ORIGINAL
# 832  CR-21-664021-A  10/06/2021           ARRESTED
#
# [713 rows x 3 columns]

# %%
charges_csv
# Out:
#        TYPE       STATUTE         CHARGE DESCRIPTION  \
# 0    INDICT     2911.12.B                   BURGLARY
# 1    INDICT  2905.02.A(1)                  ABDUCTION
# 2    INDICT  2913.02.A(1)    THEFT; AGGRAVATED THEFT
# 3    INDICT     2919.25.A          DOMESTIC VIOLENCE
# 4    INDICT  2911.11.A(1)        AGGRAVATED BURGLARY
# ..      ...           ...                        ...
# 243  INDICT     2925.11.A            DRUG POSSESSION
# 244  INDICT     2925.11.A            DRUG POSSESSION
# 245  INDICT     2925.11.A            DRUG POSSESSION
# 246  INDICT     2925.11.A            DRUG POSSESSION
# 247  INDICT     2923.24.A  POSSESSING CRIMINAL TOOLS
#
#                        DISPOSITION     CASE_NUMBER
# 0    PLD GLTY- N/C LIO-AMEND @ P/T  CR-17-618926-A
# 1                            NOLLE  CR-17-618926-A
# 2                            NOLLE  CR-17-618926-A
# 3                            NOLLE  CR-17-618926-A
# 4                            NOLLE  CR-17-620395-A
# ..                             ...             ...
# 243      PLD GLTY- N/C - IND @ P/T  CR-21-664518-A
# 244      PLD GLTY- N/C - IND @ P/T  CR-21-664801-A
# 245      PLD GLTY- N/C - IND @ P/T  CR-21-662304-A
# 246      PLD GLTY- N/C - IND @ P/T  CR-21-664021-A
# 247                          NOLLE  CR-21-664021-A
#
# [248 rows x 5 columns]

# %%
charges_csv.to_csv("charges2.csv", index=False)
actions_csv.to_csv("actions2.csv", index=False)
bonds_csv.to_csv("bonds2.csv", index=False)

# %%
df
# Out:
#        CASE_NUMBER  CASE_STATUS         JUDGE_NAME NEXT_EVENT ARRESTED_DATE  \
# 0   CR-18-624667-A  CASE CLOSED  TIMOTHY MCCORMICK        N/A           N/A
# 1   CR-18-624667-A  CASE CLOSED  TIMOTHY MCCORMICK        N/A           N/A
# 2   CR-18-624667-A  CASE CLOSED  TIMOTHY MCCORMICK        N/A           N/A
# 3   CR-18-624667-A  CASE CLOSED  TIMOTHY MCCORMICK        N/A           N/A
# 4   CR-18-624667-A  CASE CLOSED  TIMOTHY MCCORMICK        N/A           N/A
# ..             ...          ...                ...        ...           ...
# 95  CR-18-624667-A  CASE CLOSED  TIMOTHY MCCORMICK        N/A           N/A
# 96  CR-18-624667-A  CASE CLOSED  TIMOTHY MCCORMICK        N/A           N/A
# 97  CR-18-624667-A  CASE CLOSED  TIMOTHY MCCORMICK        N/A           N/A
# 98  CR-18-624667-A  CASE CLOSED  TIMOTHY MCCORMICK        N/A           N/A
# 99  CR-18-624667-A  CASE CLOSED  TIMOTHY MCCORMICK        N/A           N/A
#
#    ARRESTING_AGENCY ARRESTING_AGENCY_REPORT COURT_OF_APPEALS_CASE  \
# 0             PARMA                     N/A                   N/A
# 1             PARMA                     N/A                   N/A
# 2             PARMA                     N/A                   N/A
# 3             PARMA                     N/A                   N/A
# 4             PARMA                     N/A                   N/A
# ..              ...                     ...                   ...
# 95            PARMA                     N/A                   N/A
# 96            PARMA                     N/A                   N/A
# 97            PARMA                     N/A                   N/A
# 98            PARMA                     N/A                   N/A
# 99            PARMA                     N/A                   N/A
#
#    DEFENDANT_NUMBER             DEFENDANT_NAME DEFENDANT_STATUS DEFENDANT_DOB  \
# 0            182340  XAVIER A HARRIS HEMPSTEAD      DEFN LVJAIL    07/26/1984
# 1            182340  XAVIER A HARRIS HEMPSTEAD      DEFN LVJAIL    07/26/1984
# 2            182340  XAVIER A HARRIS HEMPSTEAD      DEFN LVJAIL    07/26/1984
# 3            182340  XAVIER A HARRIS HEMPSTEAD      DEFN LVJAIL    07/26/1984
# 4            182340  XAVIER A HARRIS HEMPSTEAD      DEFN LVJAIL    07/26/1984
# ..              ...                        ...              ...           ...
# 95           182340  XAVIER A HARRIS HEMPSTEAD      DEFN LVJAIL    07/26/1984
# 96           182340  XAVIER A HARRIS HEMPSTEAD      DEFN LVJAIL    07/26/1984
# 97           182340  XAVIER A HARRIS HEMPSTEAD      DEFN LVJAIL    07/26/1984
# 98           182340  XAVIER A HARRIS HEMPSTEAD      DEFN LVJAIL    07/26/1984
# 99           182340  XAVIER A HARRIS HEMPSTEAD      DEFN LVJAIL    07/26/1984
#
#    DEFENDANT_RACE DEFENDANT_SEX  \
# 0           BLACK          MALE
# 1           BLACK          MALE
# 2           BLACK          MALE
# 3           BLACK          MALE
# 4           BLACK          MALE
# ..            ...           ...
# 95          BLACK          MALE
# 96          BLACK          MALE
# 97          BLACK          MALE
# 98          BLACK          MALE
# 99          BLACK          MALE
#
#                                           OTHER_CASES CO_DEFENDANTS
# 0   CR-15-595398-A, CR-14-588420-B, CR-14-583841-A...           N/A
# 1   CR-15-595398-A, CR-14-588420-B, CR-14-583841-A...           N/A
# 2   CR-15-595398-A, CR-14-588420-B, CR-14-583841-A...           N/A
# 3   CR-15-595398-A, CR-14-588420-B, CR-14-583841-A...           N/A
# 4   CR-15-595398-A, CR-14-588420-B, CR-14-583841-A...           N/A
# ..                                                ...           ...
# 95  CR-15-595398-A, CR-14-588420-B, CR-14-583841-A...           N/A
# 96  CR-15-595398-A, CR-14-588420-B, CR-14-583841-A...           N/A
# 97  CR-15-595398-A, CR-14-588420-B, CR-14-583841-A...           N/A
# 98  CR-15-595398-A, CR-14-588420-B, CR-14-583841-A...           N/A
# 99  CR-15-595398-A, CR-14-588420-B, CR-14-583841-A...           N/A
#
# [100 rows x 16 columns]

# %% [markdown]
# # h-list

# %%
already_scraped = list(df["CASE_NUMBER"].unique())

# %%
new_cases = ["618926",
"620395",
"616872",
"620865",
"614781",
"628724",
"631170",
"627746",
"635840",
"633911",
"646343",
"646590",
"641595",
"641983",
"647080",
"650202",
"650473",
"649886",
"648192",
"648166",
"666430",
"657457",
"663574",
"660005",
"665568",
"616263",
"613712",
"618748",
"615216",
"619363",
"625226",
"625071",
"633620",
"627879",
"627879",
"644646",
"645807",
"640586",
"646354",
"642321",
"652069",
"651583",
"655333",
"653793",
"653048",
"660255",
"662286",
"662347",
"656397",
"660002",
"619447",
"621879",
"619539",
"619626",
"619180",
"628630",
"627817",
"633075",
"629819",
"627173",
"640255",
"645111",
"646461",
"636695",
"644912",
"655597",
"653681",
"651825",
"654631",
"651363",
"656323",
"665547",
"659751",
"662658",
"662176",
"619386",
"619384",
"619846",
"623628",
"619478",
"626510",
"634952",
"631300",
"635457",
"630824",
"643838",
"645684",
"636488",
"642792",
"636996",
"652397",
"648833",
"648433",
"653455",
"647816",
"664281",
"664518",
"664801",
"662304",
"664021"]

# %%
set(new_cases).intersection(set(case_numbers))
# Out:
# set()
